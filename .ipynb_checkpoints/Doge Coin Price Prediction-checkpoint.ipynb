# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
data = pd.read_csv("DOGE-USD.csv")

# %%
data.head()
# Out:
#          Date      Open      High       Low     Close   Volume
# 0  2017-11-09  0.001207  0.001415  0.001181  0.001415  6259550
# 1  2017-11-10  0.001421  0.001431  0.001125  0.001163  4246520
# 2  2017-11-11  0.001146  0.001257  0.001141  0.001201  2231080
# 3  2017-11-12  0.001189  0.001210  0.001002  0.001038  3288960
# 4  2017-11-13  0.001046  0.001212  0.001019  0.001211  2481270

# %%
data.tail()
# Out:
#             Date      Open      High       Low     Close      Volume
# 1527  2022-01-14  0.172053  0.203232  0.171283  0.183549  5784004926
# 1528  2022-01-15  0.183644  0.193600  0.182676  0.185103  1878282290
# 1529  2022-01-16  0.185093  0.185093  0.175327  0.177176  1102750171
# 1530  2022-01-17  0.177187  0.177872  0.166891  0.171145  1094379303
# 1531  2022-01-18  0.171080  0.173651  0.165412  0.166144  1150345216

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1532 entries, 0 to 1531
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    1532 non-null   object
#  1   Open    1532 non-null   float64
#  2   High    1532 non-null   float64
#  3   Low     1532 non-null   float64
#  4   Close   1532 non-null   float64
#  5   Volume  1532 non-null   int64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 71.9+ KB

# %%
data.isnull().any()
# Out:
# Date      False
# Open      False
# High      False
# Low       False
# Close     False
# Volume    False
# dtype: bool

# %%
data.describe()
# Out:
#               Open         High          Low        Close        Volume
# count  1532.000000  1532.000000  1532.000000  1532.000000  1.532000e+03
# mean      0.053032     0.056574     0.049593     0.053151  1.049954e+09
# std       0.106257     0.114770     0.097944     0.106358  3.809881e+09
# min       0.001046     0.001210     0.001002     0.001038  1.431720e+06
# 25%       0.002494     0.002551     0.002430     0.002495  1.965492e+07
# 50%       0.003161     0.003260     0.003059     0.003162  6.806869e+07
# 75%       0.009115     0.009615     0.008515     0.009195  2.837324e+08
# max       0.687801     0.737567     0.608168     0.684777  6.941068e+10

# %%
plt.figure(figsize=(10,10))
sns.heatmap(data.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
X = data['Close']

# %%
X.head()
# Out:
# 0    0.001415
# 1    0.001163
# 2    0.001201
# 3    0.001038
# 4    0.001211
# Name: Close, dtype: float64

# %%
X = np.array(X).reshape(-1,1)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
X = scaler.fit_transform(X)

# %%
X
# Out:
# array([[0.001415],
#        [0.001163],
#        [0.001201],
#        ...,
#        [0.177176],
#        [0.171145],
#        [0.166144]])

# %%
x_data = []
y_data = []
column_len = 25
for i in range(len(X)-column_len-1):
    x_data.append(X[i:i+column_len,0])
    y_data.append(X[i+column_len,0])

# %%
x_data
# Out:
# [array([0.001415, 0.001163, 0.001201, 0.001038, 0.001211, 0.001184,
#         0.001339, 0.00139 , 0.001313, 0.001373, 0.001376, 0.001394,
#         0.001389, 0.001823, 0.001891, 0.001908, 0.002072, 0.002026,
#         0.001988, 0.002363, 0.00208 , 0.002079, 0.002148, 0.002149,
#         0.002223]),
#  array([0.001163, 0.001201, 0.001038, 0.001211, 0.001184, 0.001339,
#         0.00139 , 0.001313, 0.001373, 0.001376, 0.001394, 0.001389,
#         0.001823, 0.001891, 0.001908, 0.002072, 0.002026, 0.001988,
#         0.002363, 0.00208 , 0.002079, 0.002148, 0.002149, 0.002223,
#         0.002463]),
#  array([0.001201, 0.001038, 0.001211, 0.001184, 0.001339, 0.00139 ,
#         0.001313, 0.001373, 0.001376, 0.001394, 0.001389, 0.001823,
#         0.001891, 0.001908, 0.002072, 0.002026, 0.001988, 0.002363,
#         0.00208 , 0.002079, 0.002148, 0.002149, 0.002223, 0.002463,
#         0.002479]),
#  array([0.001038, 0.001211, 0.001184, 0.001339, 0.00139 , 0.001313,
# ...

# %%
y_data
# Out:
# [0.002463,
#  0.002479,
#  0.002663,
#  0.00272,
#  0.002779,
#  0.002617,
#  0.002547,
#  0.002798,
#  0.003304,
#  0.003461,
#  0.003709,
#  0.003762,
#  0.005933,
#  0.005984,
#  0.006433,
#  0.005666,
#  0.006661,
#  0.007425,
#  0.006054,
#  0.007259,
#  0.008582,
#  0.008931,
#  0.009411,
#  0.008872,
#  0.008486,
#  0.009391,
#  0.00786,
#  0.008972,
#  0.008909,
#  0.009145,
#  0.00932,
#  0.009644,
#  0.012167,
#  0.014863,
#  0.017088,
#  0.015045,
#  0.01342,
#  0.013102,
#  0.011469,
#  0.013056,
#  0.013023,
#  0.011684,
#  0.009857,
#  0.006822,
#  0.007648,
#  0.007969,
#  0.007871,
#  0.008448,
#  0.007131,
#  0.006734,
#  0.006673,
#  0.007083,
#  0.007667,
#  0.007237,
#  0.007373,
#  0.007465,
#  0.006967,
#  0.006024,
#  0.00601,
#  0.005029,
#  0.004475,
#  0.005164,
#  0.004399,
#  0.003533,
#  0.004361,
#  0.004297,
#  0.004566,
#  0.005,
#  0.004989,
#  0.004956,
#  0.005472,
#  0.005638,
#  0.00673,
#  0.007347,
#  0.007034,
#  0.007049,
#  0.006424,
# ...

# %%
np.array(x_data).shape
# Out:
# (1506, 25)

# %%
x_data = np.array(x_data)
y_data = np.array(y_data)

# %%
x_data
# Out:
# array([[5.51379986e-04, 1.82818298e-04, 2.38395060e-04, ...,
#         1.62488903e-03, 1.73311746e-03, 2.08412859e-03],
#        [1.82818298e-04, 2.38395060e-04, 0.00000000e+00, ...,
#         1.73311746e-03, 2.08412859e-03, 2.10752934e-03],
#        [2.38395060e-04, 0.00000000e+00, 2.53020524e-04, ...,
#         2.08412859e-03, 2.10752934e-03, 2.37663787e-03],
#        ...,
#        [2.48833254e-01, 2.51815386e-01, 2.68307059e-01, ...,
#         2.50102744e-01, 2.66930803e-01, 2.69203600e-01],
#        [2.51815386e-01, 2.68307059e-01, 2.71425208e-01, ...,
#         2.66930803e-01, 2.69203600e-01, 2.57609994e-01],
#        [2.68307059e-01, 2.71425208e-01, 2.77326582e-01, ...,
#         2.69203600e-01, 2.57609994e-01, 2.48789377e-01]])

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train, y_test = train_test_split(x_data, y_data, test_size=0.25)

# %%
x_test.shape
# Out:
# (377, 26)

# %%
model = RandomForestRegressor()

# %%
# model.fit(x_train, y_train)
model.fit(x_data, y_data)
# Out:
# RandomForestRegressor()

# %%
y_pred = model.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
# Out:
# array([[5.51379986e-04],
#        [1.82818298e-04],
#        [2.38395060e-04],
#        ...,
#        [2.57609994e-01],
#        [2.48789377e-01],
#        [2.41475183e-01]])

# %%
c = np.concatenate((c[1:],model.predict(x_data[-1].reshape(1,-1)).reshape(1,-1)))

# %%
model.predict(x_data[-1].reshape(1,-1)).reshape(1,-1)
# Out:
# array([[0.25199187]])

# %%
c = X[len(X)-25:]

# %%
c.shape
# Out:
# (25, 1)

# %%
model.predict(c.reshape(1,-1))
# Out:
# array([0.25235977])

# %%
c
# Out:
# array([[0.27639494],
#        [0.27300915],
#        [0.25313607],
#        [0.24384597],
#        [0.24903509],
#        [0.24784018],
#        [0.25155359],
#        [0.25355435],
#        [0.24724347],
#        [0.24536409],
#        [0.23164102],
#        [0.23280082],
#        [0.2252102 ],
#        [0.22072165],
#        [0.21942145],
#        [0.20815106],
#        [0.22283503],
#        [0.23490542],
#        [0.25010274],
#        [0.2669308 ],
#        [0.2692036 ],
#        [0.25760999],
#        [0.24878938],
#        [0.24147518],
#        [0.25199187]])

# %%
np.concatenate((c[1:],c[1:]))
# Out:
# array([[0.27639494],
#        [0.27300915],
#        [0.25313607],
#        [0.24384597],
#        [0.24903509],
#        [0.24784018],
#        [0.25155359],
#        [0.25355435],
#        [0.24724347],
#        [0.24536409],
#        [0.23164102],
#        [0.23280082],
#        [0.2252102 ],
#        [0.22072165],
#        [0.21942145],
#        [0.20815106],
#        [0.22283503],
#        [0.23490542],
#        [0.25010274],
#        [0.2669308 ],
#        [0.2692036 ],
#        [0.25760999],
#        [0.24878938],
#        [0.24147518],
#        [0.27639494],
#        [0.27300915],
#        [0.25313607],
#        [0.24384597],
#        [0.24903509],
#        [0.24784018],
#        [0.25155359],
#        [0.25355435],
#        [0.24724347],
#        [0.24536409],
#        [0.23164102],
#        [0.23280082],
#        [0.2252102 ],
#        [0.22072165],
#        [0.21942145],
#        [0.20815106],
#        [0.22283503],
#        [0.23490542],
#        [0.25010274],
# ...

# %%
a = 10
for _ in range(10):
    x = model.predict(c.reshape(1,-1)).reshape(1,-1)
    c = np.concatenate((c[1:], x))
    print(x)
# Out:
# [[0.16424611]]
# [[0.16341508]]
# [[0.16475853]]
# [[0.162162]]
# [[0.16211378]]
# [[0.16343025]]
# [[0.16505121]]
# [[0.16601839]]
# [[0.16576036]]
# [[0.16558542]]

# %%
y_data
# Out:
# array([0.002463, 0.002479, 0.002663, ..., 0.185103, 0.177176, 0.171145])

# %%
import datetime

# %%
from datetime import date

d0 = date(2008, 7, 19)
d1 = date(2008, 9, 26)
delta = d1 - d0
print(delta.days)
# Out:
#   File "C:\Users\basil\AppData\Local\Temp/ipykernel_16648/1832583408.py", line 3
#     d0 = date(2008, 07, 19)
#                      ^
# SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers

# %%
import pickle

file = open('model.pkl', 'wb')
pickle.dump(model, file)

# %%
x = "sfdas"

# %%
x.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16648/1711638782.py in <module>
# ----> 1 x.type
#
# AttributeError: 'str' object has no attribute 'type'

# %%
type(x)
# Out:
# str
